# %% [markdown]
# ### Plot (Revisi)

# %% [markdown]
# #### Daftar Isi:
# - [1. Performa](#1-performa)
#     - [1.1 Pelatihan](#11-pelatihan)
#     - [1.2 Pelatihan vs. Pengujian](#12-pelatihan-vs-pengujian)
# - [2. Hyperparameter](#2-hyperparameter)
# - [3. Hyperparameter vs. Performa](#3-hyperparameter-vs-performa)
# - [4. Confusion Matrix](#4-confusion-matrix)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %load_ext watermark
# %watermark -a 'Waskito' -n -t -u -v
# Out:
# Author: Waskito
#
# Last updated: Fri Jan 26 2024 16:44:50
#
# Python implementation: CPython
# Python version       : 3.9.18
# IPython version      : 8.15.0

# %%
import pandas
from collection import analysis
from collection import helper

# %%
# Hasil pelatihan (k = 5)
train_k5_linear_bow = pandas.read_csv("data/result/train/train_k5_linear_bow.csv")
train_k5_linear_tfidf = pandas.read_csv("data/result/train/train_k5_linear_tfidf.csv")
train_k5_rbf_bow = pandas.read_csv("data/result/train/train_k5_rbf_bow.csv")
train_k5_rbf_tfidf = pandas.read_csv("data/result/train/train_k5_rbf_tfidf.csv")
train_k5_poly_bow = pandas.read_csv("data/result/train/train_k5_poly_bow.csv")
train_k5_poly_tfidf = pandas.read_csv("data/result/train/train_k5_poly_tfidf.csv")

# Hasil pelatihan (k = 10)
train_k10_linear_bow = pandas.read_csv("data/result/train/train_k10_linear_bow.csv")
train_k10_linear_tfidf = pandas.read_csv("data/result/train/train_k10_linear_tfidf.csv")
train_k10_rbf_bow = pandas.read_csv("data/result/train/train_k10_rbf_bow.csv")
train_k10_rbf_tfidf = pandas.read_csv("data/result/train/train_k10_rbf_tfidf.csv")
train_k10_poly_bow = pandas.read_csv("data/result/train/train_k10_poly_bow.csv")
train_k10_poly_tfidf = pandas.read_csv("data/result/train/train_k10_poly_tfidf.csv")

# %%
# Hasil pengujian
test_linear_bow = pandas.read_csv("data/result/test/test_linear_bow.csv")
test_linear_tfidf = pandas.read_csv("data/result/test/test_linear_tfidf.csv")
test_rbf_bow = pandas.read_csv("data/result/test/test_rbf_bow.csv")
test_rbf_tfidf = pandas.read_csv("data/result/test/test_rbf_tfidf.csv")
test_poly_bow = pandas.read_csv("data/result/test/test_poly_bow.csv")
test_poly_tfidf = pandas.read_csv("data/result/test/test_poly_tfidf.csv")

# Hasil pengujian terbaik
test_best_linear_bow = pandas.read_csv("data/result/test/test_linear_bow[best].csv")
test_best_linear_tfidf = pandas.read_csv("data/result/test/test_linear_tfidf[best].csv")
test_best_rbf_bow = pandas.read_csv("data/result/test/test_rbf_bow[best].csv")
test_best_rbf_tfidf = pandas.read_csv("data/result/test/test_rbf_tfidf[best].csv")
test_best_poly_bow = pandas.read_csv("data/result/test/test_poly_bow[best].csv")
test_best_poly_tfidf = pandas.read_csv("data/result/test/test_poly_tfidf[best].csv")

# Confusion matrix hasil pengujian terbaik
test_best_cm_linear_bow = pandas.read_csv("data/result/test/test_linear_bow[best-cm].csv")
test_best_cm_linear_tfidf = pandas.read_csv("data/result/test/test_linear_tfidf[best-cm].csv")
test_best_cm_rbf_bow = pandas.read_csv("data/result/test/test_rbf_bow[best-cm].csv")
test_best_cm_rbf_tfidf = pandas.read_csv("data/result/test/test_rbf_tfidf[best-cm].csv")
test_best_cm_poly_bow = pandas.read_csv("data/result/test/test_poly_bow[best-cm].csv")
test_best_cm_poly_tfidf = pandas.read_csv("data/result/test/test_poly_tfidf[best-cm].csv")

test_best_cm_linear_bow.drop("Unnamed: 0", axis=1, inplace=True)
test_best_cm_linear_tfidf.drop("Unnamed: 0", axis=1, inplace=True)
test_best_cm_rbf_bow.drop("Unnamed: 0", axis=1, inplace=True)
test_best_cm_rbf_tfidf.drop("Unnamed: 0", axis=1, inplace=True)
test_best_cm_poly_bow.drop("Unnamed: 0", axis=1, inplace=True)
test_best_cm_poly_tfidf.drop("Unnamed: 0", axis=1, inplace=True)

# %% [markdown]
# ***
# ***

# %% [markdown]
# ### __1. Performa__

# %% [markdown]
# #### __1.1 Pelatihan__

# %% [markdown]
# ##### 1.1.1 Kernel Linear

# %% [markdown]
# ##### 1.1.1.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "Linear-BoW": {
        "Iterasi": pandas.Series(range(len(train_k5_linear_bow))),
        "Akurasi": train_k5_linear_bow["mean_accuracy"]
    },
    "Linear-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_k5_linear_tfidf))),
        "Akurasi": train_k5_linear_tfidf["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="lower left",
    title="Performa Kernel Linear pada Pelatihan ($k=5$)",
)

# %% [markdown]
# ##### 1.1.1.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "Linear-BoW": {
        "Iterasi": pandas.Series(range(len(train_k10_linear_bow))),
        "Akurasi": train_k10_linear_bow["mean_accuracy"]
    },
    "Linear-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_k10_linear_tfidf))),
        "Akurasi": train_k10_linear_tfidf["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="lower left",
    title="Performa Kernel Linear pada Pelatihan ($k=10$)",
)

# %% [markdown]
# #### 1.1.2 Kernel RBF

# %% [markdown]
# ##### 1.1.2.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "RBF-BoW": {
        "Iterasi": pandas.Series(range(len(train_k5_rbf_bow))),
        "Akurasi": train_k5_rbf_bow["mean_accuracy"]
    },
    "RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_k5_rbf_tfidf))),
        "Akurasi": train_k5_rbf_tfidf["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="lower right",
    title="Performa Kernel RBF pada Pelatihan ($k=5$)",
)

# %% [markdown]
# ##### 1.1.2.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "RBF-BoW": {
        "Iterasi": pandas.Series(range(len(train_k10_rbf_bow))),
        "Akurasi": train_k10_rbf_bow["mean_accuracy"]
    },
    "RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_k10_rbf_tfidf))),
        "Akurasi": train_k10_rbf_tfidf["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="lower right",
    title="Performa Kernel RBF pada Pelatihan ($k=10$)",
)

# %% [markdown]
# #### 1.1.3 SVM-Poly

# %% [markdown]
# ##### 1.1.3.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "Poly-BoW": {
        "Iterasi": pandas.Series(range(len(train_k5_poly_bow))),
        "Akurasi": train_k5_poly_bow["mean_accuracy"]
    },
    "RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_k5_poly_tfidf))),
        "Akurasi": train_k5_poly_tfidf["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="upper left",
    title="Performa Kernel Polinomial pada Pelatihan ($k=5$)",
    figsize=(9, 4.8),
    ticksize=[8, 10],
)

# %% [markdown]
# ##### 1.1.3.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "Poly-BoW": {
        "Iterasi": pandas.Series(range(len(train_k10_poly_bow))),
        "Akurasi": train_k10_poly_bow["mean_accuracy"]
    },
    "RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_k10_poly_tfidf))),
        "Akurasi": train_k10_poly_tfidf["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="upper left",
    title="Performa Kernel Polinomial pada Pelatihan ($k=10$)",
    figsize=(9, 4.8),
    ticksize=[8, 10],
)

# %% [markdown]
# #### __1.2. Pelatihan & Pengujian__

# %% [markdown]
# ##### 1.2.1 Linear-BoW

# %%
res_dict = {
    "Pelatihan ($k=5$)": {
        "Iterasi": pandas.Series(range(len(train_k5_linear_bow))),
        "Akurasi": train_k5_linear_bow["mean_accuracy"]
    },
    "Pelatihan ($k=10$)": {
        "Iterasi": pandas.Series(range(len(train_k10_linear_bow))),
        "Akurasi": train_k10_linear_bow["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_linear_bow))),
        "Akurasi": test_linear_bow["accuracy"]
    },
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="lower left",
    title="Performa Linear-BoW pada Pelatihan & Pengujian",
)

# %% [markdown]
# ##### 1.2.2 Linear-TFIDF

# %%
res_dict = {
    "Pelatihan ($k=5$)": {
        "Iterasi": pandas.Series(range(len(train_k5_linear_tfidf))),
        "Akurasi": train_k5_linear_tfidf["mean_accuracy"]
    },
    "Pelatihan ($k=10$)": {
        "Iterasi": pandas.Series(range(len(train_k10_linear_tfidf))),
        "Akurasi": train_k10_linear_tfidf["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_linear_tfidf))),
        "Akurasi": test_linear_tfidf["accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="lower left",
    title="Performa Linear-TFIDF pada Pelatihan & Pengujian",
)

# %% [markdown]
# ##### 1.2.3 RBF-BoW

# %%
res_dict = {
    "Pelatihan ($k=5$)": {
        "Iterasi": pandas.Series(range(len(train_k5_rbf_bow))),
        "Akurasi": train_k5_rbf_bow["mean_accuracy"]
    },
    "Pelatihan ($k=10$)": {
        "Iterasi": pandas.Series(range(len(train_k10_rbf_bow))),
        "Akurasi": train_k10_rbf_bow["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_rbf_bow))),
        "Akurasi": test_rbf_bow["accuracy"]
    },
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="lower right",
    title="Performa RBF-BoW pada Pelatihan & Pengujian",
)

# %% [markdown]
# ##### 1.2.4 RBF-TFIDF

# %%
res_dict = {
    "Pelatihan ($k=5$)": {
        "Iterasi": pandas.Series(range(len(train_k5_rbf_tfidf))),
        "Akurasi": train_k5_rbf_tfidf["mean_accuracy"]
    },
    "Pelatihan ($k=10$)": {
        "Iterasi": pandas.Series(range(len(train_k10_rbf_tfidf))),
        "Akurasi": train_k10_rbf_tfidf["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_rbf_tfidf))),
        "Akurasi": test_rbf_tfidf["accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="lower right",
    title="Performa RBF-TFIDF pada Pelatihan & Pengujian",
)

# %% [markdown]
# ##### 1.2.5 Polinomial-BoW

# %%
res_dict = {
    "Pelatihan ($k=5$)": {
        "Iterasi": pandas.Series(range(len(train_k5_poly_bow))),
        "Akurasi": train_k5_poly_bow["mean_accuracy"]
    },
    "Pelatihan ($k=10$)": {
        "Iterasi": pandas.Series(range(len(train_k10_poly_bow))),
        "Akurasi": train_k10_poly_bow["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_poly_bow))),
        "Akurasi": test_poly_bow["accuracy"]
    },
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="upper left",
    title="Performa Polinomial-BoW pada Pelatihan & Pengujian",
    figsize=(9, 4.8),
    ticksize=[8, 10],
)

# %% [markdown]
# ##### 1.2.6 Polinomial-TFIDF

# %%
res_dict = {
    "Pelatihan ($k=5$)": {
        "Iterasi": pandas.Series(range(len(train_k5_poly_tfidf))),
        "Akurasi": train_k5_poly_tfidf["mean_accuracy"]
    },
    "Pelatihan ($k=10$)": {
        "Iterasi": pandas.Series(range(len(train_k10_poly_tfidf))),
        "Akurasi": train_k10_poly_tfidf["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_poly_tfidf))),
        "Akurasi": test_poly_tfidf["accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="lower left",
    title="Performa Polinomial-TFIDF pada Pelatihan & Pengujian",
    figsize=(9, 4.8),
    ticksize=[8, 10],
)

# %% [markdown]
# ***

# %% [markdown]
# ### __2. Hyperparameter__

# %% [markdown]
# #### __2.1 Iterasi vs. Hypeparameter__

# %%
colors = {"scatter": ["black"], "plot": ["black"]}

# %% [markdown]
# ##### 2.1.1 Kernel Linear

# %%
res_dict = {
    "Linear-BoW & Linear-TFIDF": {
        "Iterasi": pandas.Series(range(len(test_linear_bow))),
        "C": test_linear_bow["C"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter C Kernel Linear",
    best_label=False,
    colors=colors,
    figsize=(5, 4),
)

# %% [markdown]
# ##### 2.1.2 Kernel RBF

# %%
res_dict = {
    "RBF-BoW & RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(test_rbf_bow))),
        "C": test_rbf_bow["C"],
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter C Kernel RBF",
    best_label=False,
    colors=colors,
    figsize=(5, 4),
)

# %%
res_dict = {
    "RBF-BoW & RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(test_rbf_bow))),
        "Gamma": test_rbf_bow["gamma"],
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="center right",
    title="Hyperparameter Gamma Kernel RBF",
    best_label=False,
    colors=colors,
    figsize=(5, 4),
)

# %% [markdown]
# ##### 2.1.3 Kernel Polinomial

# %%
res_dict = {
    "Poly-BoW & Poly-TFIDF": {
        "Iterasi": pandas.Series(range(len(test_poly_bow))),
        "C": test_poly_bow["C"],
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter C Kernel Polinomial",
    best_label=False,
    colors=colors,
    figsize=(9, 3),
    ticksize=[8, 10],
)

# %%
res_dict = {
    "Poly-BoW & Poly-TFIDF": {
        "Iterasi": pandas.Series(range(len(test_poly_bow))),
        "Gamma": test_poly_bow["gamma"],
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend=None,
    title="Hyperparameter Gamma Kernel Polinomial",
    best_label=False,
    colors=colors,
    figsize=(9, 3),
    ticksize=[8, 10],
)

# %%
res_dict = {
    "Poly-BoW & Poly-TFIDF": {
        "Iterasi": pandas.Series(range(len(test_poly_bow))),
        "Degree": test_poly_bow["degree"],
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend=None,
    title="Hyperparameter Degree Kernel Polinomial",
    best_label=False,
    colors=colors,
    figsize=(9, 3),
    ticksize=[8, 10],
)

# %% [markdown]
# ***

# %% [markdown]
# ### __3. Hyperparameter vs. Performa__

# %% [markdown]
# #### 3.1 Kernel Linear

# %% [markdown]
# ##### 3.1.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "Linear-BoW": {
        "C": train_k5_linear_bow["C"],
        "Akurasi": train_k5_linear_bow["mean_accuracy"]
    },
    "Linear-TFIDF": {
        "C": train_k5_linear_tfidf["C"],
        "Akurasi": train_k5_linear_tfidf["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="upper right",
    title="Hyperparameter & Performa Kernel Linear pada Pelatihan ($k=5$)",
)

# %% [markdown]
# ##### 3.1.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "Linear-BoW": {
        "C": train_k10_linear_bow["C"],
        "Akurasi": train_k10_linear_bow["mean_accuracy"]
    },
    "Linear-TFIDF": {
        "C": train_k10_linear_tfidf["C"],
        "Akurasi": train_k10_linear_tfidf["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict=res_dict,
    legend="upper right",
    title="Hyperparameter & Performa Kernel Linear pada Pelatihan ($k=10$)",
)

# %% [markdown]
# #### 3.2 Kernel RBF

# %% [markdown]
# ##### 3.2.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "RBF-BoW": {
        "C": train_k5_rbf_bow["C"],
        "Gamma": train_k5_rbf_bow["gamma"],
        "Akurasi": train_k5_rbf_bow["mean_accuracy"],
    },
    "RBF-TFIDF": {
        "C": train_k5_rbf_tfidf["C"],
        "Gamma": train_k5_rbf_tfidf["gamma"],
        "Akurasi": train_k5_rbf_tfidf["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter & Performa Kernel RBF pada Pelatihan ($k=5$)",
)

# %% [markdown]
# ##### 3.2.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "RBF-BoW": {
        "C": train_k10_rbf_bow["C"],
        "Gamma": train_k10_rbf_bow["gamma"],
        "Akurasi": train_k10_rbf_bow["mean_accuracy"],
    },
    "RBF-TFIDF": {
        "C": train_k10_rbf_tfidf["C"],
        "Gamma": train_k10_rbf_tfidf["gamma"],
        "Akurasi": train_k10_rbf_tfidf["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter & Performa Kernel RBF pada Pelatihan ($k=10$)",
)

# %% [markdown]
# #### 3.3 Kernel Polinomial

# %% [markdown]
# ##### 3.3.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "Poly-BoW": {
        "C": train_k5_poly_bow["C"],
        "Gamma": train_k5_poly_bow["gamma"],
        "Akurasi": train_k5_poly_bow["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "C": train_k5_poly_tfidf["C"],
        "Gamma": train_k5_poly_tfidf["gamma"],
        "Akurasi": train_k5_poly_tfidf["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter & Performa Kernel Polinomial pada Pelatihan ($k=5$)",
)

# %%
res_dict = {
    "Poly-BoW": {
        "C": train_k5_poly_bow["C"],
        "Degree": train_k5_poly_bow["degree"],
        "Akurasi": train_k5_poly_bow["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "C": train_k5_poly_tfidf["C"],
        "Degree": train_k5_poly_tfidf["degree"],
        "Akurasi": train_k5_poly_tfidf["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter & Performa Kernel Polinomial pada Pelatihan ($k=5$)",
)

# %%
res_dict = {
    "Poly-BoW": {
        "Gamma": train_k5_poly_bow["gamma"],
        "Degree": train_k5_poly_bow["degree"],
        "Akurasi": train_k5_poly_bow["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "Gamma": train_k5_poly_tfidf["gamma"],
        "Degree": train_k5_poly_tfidf["degree"],
        "Akurasi": train_k5_poly_tfidf["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter & Performa Kernel Polinomial pada Pelatihan ($k=5$)",
)

# %% [markdown]
# ##### 3.3.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "Poly-BoW": {
        "C": train_k10_poly_bow["C"],
        "Gamma": train_k10_poly_bow["gamma"],
        "Akurasi": train_k10_poly_bow["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "C": train_k10_poly_tfidf["C"],
        "Gamma": train_k10_poly_tfidf["gamma"],
        "Akurasi": train_k10_poly_tfidf["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter & Performa Kernel Polinomial pada Pelatihan ($k=10$)",
)

# %%
res_dict = {
    "Poly-BoW": {
        "C": train_k10_poly_bow["C"],
        "Degree": train_k10_poly_bow["degree"],
        "Akurasi": train_k10_poly_bow["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "C": train_k10_poly_tfidf["C"],
        "Degree": train_k10_poly_tfidf["degree"],
        "Akurasi": train_k10_poly_tfidf["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter & Performa Kernel Polinomial pada Pelatihan ($k=10$)",
)

# %%
res_dict = {
    "Poly-BoW": {
        "Gamma": train_k10_poly_bow["gamma"],
        "Degree": train_k10_poly_bow["degree"],
        "Akurasi": train_k10_poly_bow["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "Gamma": train_k10_poly_tfidf["gamma"],
        "Degree": train_k10_poly_tfidf["degree"],
        "Akurasi": train_k10_poly_tfidf["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict=res_dict,
    legend="upper left",
    title="Hyperparameter & Performa Kernel Polinomial pada Pelatihan ($k=10$)",
)

# %% [markdown]
# ***

# %% [markdown]
# ### __4. _Confusion Matrix___

# %%
cmap = "binary"
drop_col = ["kernel", "precision", "recall"]

# %% [markdown]
# #### 4.1 Hasil Pengujian Terbaik Linear-BoW

# %%
subtitle = helper.table_to_text(
    table=test_best_linear_bow,
    drop_col=drop_col,
)

analysis.plot_confmatrix(
    cm=test_best_cm_linear_bow,
    title=f"Klasifikasi Terbaik Linear-BoW pada Pengujian\n({subtitle})\n",
    cmap=cmap,
    figsize=(5, 4),
)

# %% [markdown]
# #### 4.2 Hasil Pengujian Terbaik Linear-TFIDF

# %%
subtitle = helper.table_to_text(
    table=test_best_linear_tfidf,
    drop_col=drop_col,
)

analysis.plot_confmatrix(
    cm=test_best_cm_linear_tfidf,
    title=f"Klasifikasi Terbaik Linear-TFIDF pada Pengujian\n({subtitle})\n",
    cmap=cmap,
    figsize=(5, 4),
)

# %% [markdown]
# #### 4.3 Hasil Pengujian Terbaik RBF-BoW

# %%
subtitle = helper.table_to_text(
    table=test_best_rbf_bow,
    drop_col=drop_col,
)

analysis.plot_confmatrix(
    cm=test_best_cm_rbf_bow,
    title=f"Klasifikasi Terbaik RBF-BoW pada Pengujian\n({subtitle})\n",
    cmap=cmap,
    figsize=(5, 4),
)

# %% [markdown]
# #### 4.4 Hasil Pengujian Terbaik RBF-TFIDF

# %%
subtitle = helper.table_to_text(
    table=test_best_rbf_tfidf,
    drop_col=drop_col,
)

analysis.plot_confmatrix(
    cm=test_best_cm_rbf_tfidf,
    title=f"Klasifikasi Terbaik RBF-TFIDF pada Pengujian\n({subtitle})\n",
    cmap=cmap,
    figsize=(5, 4),
)

# %% [markdown]
# #### 4.5 Hasil Pengujian Terbaik Polinomial-BoW

# %%
subtitle = helper.table_to_text(
    table=test_best_poly_bow,
    drop_col=drop_col,
)

analysis.plot_confmatrix(
    cm=test_best_cm_poly_bow,
    title=f"Klasifikasi Terbaik Polinomial-BoW pada Pengujian\n({subtitle})\n",
    cmap=cmap,
    figsize=(5, 4),
)

# %% [markdown]
# #### 4.6 Hasil Pengujian Terbaik Polinomial-TFIDF

# %%
subtitle = helper.table_to_text(
    table=test_best_poly_tfidf,
    drop_col=drop_col,
)

analysis.plot_confmatrix(
    cm=test_best_cm_poly_tfidf,
    title=f"Klasifikasi Terbaik Polinomial-TFIDF pada Pengujian\n({subtitle})\n",
    cmap=cmap,
    figsize=(5, 4),
)
