# %% [markdown]
# ## Plot (Revisi)

# %% [markdown]
# #### Daftar Isi:
# - [1. Performa](#1-performa)
#     - [1.1 Pelatihan](#11-pelatihan)
#     - [1.2 Pelatihan vs. Pengujian](#12-pelatihan-vs-pengujian)
# - [2. Hyperparameter](#2-hyperparameter)
# - [3. Hyperparameter vs. Performa](#3-hyperparameter-vs-performa)

# %%
# %load_ext watermark
# %watermark -a 'Waskito' -n -t -u -v
# Out:
# Author: Waskito
#
# Last updated: Mon Jan 22 2024 21:02:35
#
# Python implementation: CPython
# Python version       : 3.9.18
# IPython version      : 8.15.0

# %%
import pandas
from collection import analysis

# %%
# Hasil pelatihan
train_linear_bow_k5_res = pandas.read_csv("data/result/train_result_linear_bow_k-5.csv")
train_linear_tfidf_k5_res = pandas.read_csv("data/result/train_result_linear_tfidf_k-5.csv")
train_rbf_bow_k5_res = pandas.read_csv("data/result/train_result_rbf_bow_k-5.csv")
train_rbf_tfidf_k5_res = pandas.read_csv("data/result/train_result_rbf_tfidf_k-5.csv")
train_poly_bow_k5_res = pandas.read_csv("data/result/train_result_poly_bow_k-5.csv")
train_poly_tfidf_k5_res = pandas.read_csv("data/result/train_result_poly_tfidf_k-5.csv")

train_linear_bow_k10_res = pandas.read_csv("data/result/train_result_linear_bow_k-10.csv")
train_linear_tfidf_k10_res = pandas.read_csv("data/result/train_result_linear_tfidf_k-10.csv")
train_rbf_bow_k10_res = pandas.read_csv("data/result/train_result_rbf_bow_k-10.csv")
train_rbf_tfidf_k10_res = pandas.read_csv("data/result/train_result_rbf_tfidf_k-10.csv")
train_poly_bow_k10_res = pandas.read_csv("data/result/train_result_poly_bow_k-10.csv")
train_poly_tfidf_k10_res = pandas.read_csv("data/result/train_result_poly_tfidf_k-10.csv")

# %%
# Hasil pengujian
test_linear_bow_res = pandas.read_csv("data/result/test/test_result_linear_bow.csv")
test_linear_tfidf_res = pandas.read_csv("data/result/test/test_result_linear_tfidf.csv")
test_rbf_bow_res = pandas.read_csv("data/result/test/test_result_rbf_bow.csv")
test_rbf_tfidf_res = pandas.read_csv("data/result/test/test_result_rbf_tfidf.csv")
test_poly_bow_res = pandas.read_csv("data/result/test/test_result_poly_bow.csv")
test_poly_tfidf_res = pandas.read_csv("data/result/test/test_result_poly_tfidf.csv")

# %% [markdown]
# ***
# ***

# %% [markdown]
# ### __1. Performa__

# %% [markdown]
# #### __1.1 Pelatihan__

# %% [markdown]
# ##### 1.1.1 Kernel Linear

# %% [markdown]
# ##### 1.1.1.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "Linear-BoW": {
        "Iterasi": pandas.Series(range(len(train_linear_bow_k5_res))),
        "Akurasi": train_linear_bow_k5_res["mean_accuracy"]
    },
    "Linear-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_linear_tfidf_k5_res))),
        "Akurasi": train_linear_tfidf_k5_res["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel Linear \nPelatihan (k=5): Iterasi vs Akurasi"
)

# %% [markdown]
# ##### 1.1.1.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "Linear-BoW": {
        "Iterasi": pandas.Series(range(len(train_linear_bow_k10_res))),
        "Akurasi": train_linear_bow_k10_res["mean_accuracy"]
    },
    "Linear-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_linear_tfidf_k10_res))),
        "Akurasi": train_linear_tfidf_k10_res["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel Linear \nPelatihan (k=10): Iterasi vs Akurasi"
)

# %% [markdown]
# #### 1.1.2 Kernel RBF

# %% [markdown]
# ##### 1.1.2.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "RBF-BoW": {
        "Iterasi": pandas.Series(range(len(train_rbf_bow_k5_res))),
        "Akurasi": train_rbf_bow_k5_res["mean_accuracy"]
    },
    "RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_rbf_tfidf_k5_res))),
        "Akurasi": train_rbf_tfidf_k5_res["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower right",
    "Kernel RBF \nPelatihan (k=5): Iterasi vs Akurasi"
)

# %% [markdown]
# ##### 1.1.2.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "RBF-BoW": {
        "Iterasi": pandas.Series(range(len(train_rbf_bow_k10_res))),
        "Akurasi": train_rbf_bow_k10_res["mean_accuracy"]
    },
    "RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_rbf_tfidf_k10_res))),
        "Akurasi": train_rbf_tfidf_k10_res["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower right",
    "Kernel RBF \nPelatihan (k=10): Iterasi vs Akurasi"
)

# %% [markdown]
# #### 1.1.3 SVM-Poly

# %% [markdown]
# ##### 1.1.3.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "Poly-BoW": {
        "Iterasi": pandas.Series(range(len(train_poly_bow_k5_res))),
        "Akurasi": train_poly_bow_k5_res["mean_accuracy"]
    },
    "RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_poly_tfidf_k5_res))),
        "Akurasi": train_poly_tfidf_k5_res["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "upper left",
    "Kernel Polinomial \nPelatihan (k=5): Iterasi vs Akurasi"
)

# %% [markdown]
# ##### 1.1.3.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "Poly-BoW": {
        "Iterasi": pandas.Series(range(len(train_poly_bow_k10_res))),
        "Akurasi": train_poly_bow_k10_res["mean_accuracy"]
    },
    "RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_poly_tfidf_k10_res))),
        "Akurasi": train_poly_tfidf_k10_res["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "upper left",
    "Kernel Polinomial \nPelatihan (k=10): Iterasi vs Akurasi"
)

# %% [markdown]
# #### __1.2. Pelatihan vs. Pengujian__

# %% [markdown]
# ##### 1.2.1 Linear-BoW

# %%
res_dict = {
    "Pelatihan (k=5)": {
        "Iterasi": pandas.Series(range(len(train_linear_bow_k5_res))),
        "Akurasi": train_linear_bow_k5_res["mean_accuracy"]
    },
    "Pelatihan (k=10)": {
        "Iterasi": pandas.Series(range(len(train_linear_bow_k10_res))),
        "Akurasi": train_linear_bow_k10_res["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_linear_bow_res))),
        "Akurasi": test_linear_bow_res["accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel Linear + BoW:\nPelatihan vs. Pengujian"
)

# %% [markdown]
# ##### 1.2.2 Linear-TFIDF

# %%
res_dict = {
    "Pelatihan (k=5)": {
        "Iterasi": pandas.Series(range(len(train_linear_tfidf_k5_res))),
        "Akurasi": train_linear_tfidf_k5_res["mean_accuracy"]
    },
    "Pelatihan (k=10)": {
        "Iterasi": pandas.Series(range(len(train_linear_tfidf_k10_res))),
        "Akurasi": train_linear_tfidf_k10_res["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_linear_tfidf_res))),
        "Akurasi": test_linear_tfidf_res["accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel Linear + TF-IDF:\nPelatihan vs. Pengujian"
)

# %% [markdown]
# ##### 1.2.3 RBF-BoW

# %%
res_dict = {
    "Pelatihan (k=5)": {
        "Iterasi": pandas.Series(range(len(train_rbf_bow_k5_res))),
        "Akurasi": train_rbf_bow_k5_res["mean_accuracy"]
    },
    "Pelatihan (k=10)": {
        "Iterasi": pandas.Series(range(len(train_rbf_bow_k10_res))),
        "Akurasi": train_rbf_bow_k10_res["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_rbf_bow_res))),
        "Akurasi": test_rbf_bow_res["accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel RBF + BoW:\nPelatihan vs. Pengujian"
)

# %% [markdown]
# ##### 1.2.4 RBF-TFIDF

# %%
res_dict = {
    "Pelatihan (k=5)": {
        "Iterasi": pandas.Series(range(len(train_rbf_tfidf_k5_res))),
        "Akurasi": train_rbf_tfidf_k5_res["mean_accuracy"]
    },
    "Pelatihan (k=10)": {
        "Iterasi": pandas.Series(range(len(train_rbf_tfidf_k10_res))),
        "Akurasi": train_rbf_tfidf_k10_res["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_rbf_tfidf_res))),
        "Akurasi": test_rbf_tfidf_res["accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel RBF + TF-IDF:\nPelatihan vs. Pengujian"
)

# %% [markdown]
# ##### 1.2.5 Polinomial-BoW

# %%
res_dict = {
    "Pelatihan (k=5)": {
        "Iterasi": pandas.Series(range(len(train_poly_bow_k5_res))),
        "Akurasi": train_poly_bow_k5_res["mean_accuracy"]
    },
    "Pelatihan (k=10)": {
        "Iterasi": pandas.Series(range(len(train_poly_bow_k10_res))),
        "Akurasi": train_poly_bow_k10_res["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_poly_bow_res))),
        "Akurasi": test_poly_bow_res["accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel Polinomial + BoW:\nPelatihan vs. Pengujian"
)

# %% [markdown]
# ##### 1.2.6 Polinomial-TFIDF

# %%
res_dict = {
    "Pelatihan (k=5)": {
        "Iterasi": pandas.Series(range(len(train_poly_tfidf_k5_res))),
        "Akurasi": train_poly_tfidf_k5_res["mean_accuracy"]
    },
    "Pelatihan (k=10)": {
        "Iterasi": pandas.Series(range(len(train_poly_tfidf_k10_res))),
        "Akurasi": train_poly_tfidf_k10_res["mean_accuracy"]
    },
    "Pengujian": {
        "Iterasi": pandas.Series(range(len(test_poly_tfidf_res))),
        "Akurasi": test_poly_tfidf_res["accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel Polinomial + TF-IDF:\nPelatihan vs. Pengujian"
)

# %% [markdown]
# ***

# %% [markdown]
# ### __2. Hyperparameter__

# %% [markdown]
# #### __2.1 Iterasi vs. Hypeparameter__

# %% [markdown]
# ##### 2.1.1 Kernel Linear

# %%
res_dict = {
    "Linear-BoW & Linear-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_linear_bow_k5_res))),
        "C": train_linear_bow_k5_res["C"]
    }
}

analysis.plot_performance_2d(
    res_dict = res_dict,
    legend = "upper left",
    title = "Hyperparameter Kernel Linear:\nIterasi vs C",
    best_label = False,
    colors = {"scatter": ["black"], "plot": ["gray"]},
)

# %% [markdown]
# ##### 2.1.2 Kernel RBF

# %%
res_dict = {
    "RBF-BoW & RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_rbf_bow_k5_res))),
        "C": train_rbf_bow_k5_res["C"]
    }
}

analysis.plot_performance_2d(
    res_dict = res_dict,
    legend = "upper left",
    title = "Hyperparameter Kernel RBF:\nIterasi vs C",
    best_label = False,
    colors = {"scatter": ["black"], "plot": ["gray"]},
)

# %%
res_dict = {
    "RBF-BoW & RBF-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_rbf_bow_k5_res))),
        "$\gamma$": train_rbf_bow_k5_res["gamma"]
    }
}

analysis.plot_performance_2d(
    res_dict = res_dict,
    legend = "center right",
    title = "Hyperparameter Kernel RBF:\nIterasi vs $\gamma$",
    best_label = False,
    colors = {"scatter": ["black"], "plot": ["gray"]},
)

# %% [markdown]
# ##### 2.1.3 Kernel Polinomial

# %%
res_dict = {
    "Poly-BoW & Poly-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_poly_bow_k5_res))),
        "C": train_poly_bow_k5_res["C"]
    }
}

analysis.plot_performance_2d(
    res_dict = res_dict,
    legend = "upper left",
    title = "Hyperparameter Kernel Polinomial:\n Iterasi vs C",
    best_label = False,
    colors = {"scatter": ["black"], "plot": ["gray"]},
)

# %%
res_dict = {
    "Poly-BoW & Poly-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_poly_bow_k5_res))),
        "$\gamma$": train_poly_bow_k5_res["gamma"]
    }
}

analysis.plot_performance_2d(
    res_dict = res_dict,
    legend = None,
    title = "Hyperparameter Kernel Polinomial:\nIterasi vs $\gamma$",
    best_label = False,
    colors = {"scatter": ["black"], "plot": ["gray"]},
)

# %%
res_dict = {
    "Poly-BoW & Poly-TFIDF": {
        "Iterasi": pandas.Series(range(len(train_poly_bow_k5_res))),
        "Degree": train_poly_bow_k5_res["degree"]
    }
}

analysis.plot_performance_2d(
    res_dict = res_dict,
    legend = None,
    title = "Hyperparameter Kernel Polinomial:\nIterasi vs Degree",
    best_label = False,
    colors = {"scatter": ["black"], "plot": ["gray"]},
)

# %% [markdown]
# ***

# %% [markdown]
# ### __3. Hyperparameter vs. Performa__

# %% [markdown]
# ##### 3.1 Kernel Linear

# %% [markdown]
# ##### 3.1.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "Linear-BoW": {
        "C": train_linear_bow_k5_res["C"],
        "Akurasi": train_linear_bow_k5_res["mean_accuracy"]
    },
    "Linear-TFIDF": {
        "C": train_linear_tfidf_k5_res["C"],
        "Akurasi": train_linear_tfidf_k5_res["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel Linear \nPelatihan(k=5):C vs Akurasi"
)

# %% [markdown]
# ##### 3.1.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "Linear-BoW": {
        "C": train_linear_bow_k10_res["C"],
        "Akurasi": train_linear_bow_k10_res["mean_accuracy"]
    },
    "Linear-TFIDF": {
        "C": train_linear_tfidf_k10_res["C"],
        "Akurasi": train_linear_tfidf_k10_res["mean_accuracy"]
    }
}

analysis.plot_performance_2d(
    res_dict,
    "lower left",
    "Kernel Linear \nPelatihan (k=10): C vs Akurasi"
)

# %% [markdown]
# #### 3.2 Kernel RBF

# %% [markdown]
# ##### 3.2.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "RBF-BoW": {
        "C": train_rbf_bow_k5_res["C"],
        "$\gamma$": train_rbf_bow_k5_res["gamma"],
        "Akurasi": train_rbf_bow_k5_res["mean_accuracy"],
    },
    "RBF-TFIDF": {
        "C": train_rbf_tfidf_k5_res["C"],
        "$\gamma$": train_rbf_tfidf_k5_res["gamma"],
        "Akurasi": train_rbf_tfidf_k5_res["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict,
    "upper left",
    "Kernel RBF \nPelatihan (k=5): C vs. $\gamma$ vs. Akurasi"
)

# %% [markdown]
# ##### 3.2.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "RBF-BoW": {
        "C": train_rbf_bow_k10_res["C"],
        "$\gamma$": train_rbf_bow_k10_res["gamma"],
        "Akurasi": train_rbf_bow_k10_res["mean_accuracy"],
    },
    "RBF-TFIDF": {
        "C": train_rbf_tfidf_k10_res["C"],
        "$\gamma$": train_rbf_tfidf_k10_res["gamma"],
        "Akurasi": train_rbf_tfidf_k10_res["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict,
    "upper left",
    "Kernel RBF \nPelatihan (k=10): C vs. $\gamma$ vs. Akurasi"
)

# %% [markdown]
# ##### 3.3 Kernel Polinomial

# %% [markdown]
# ##### 3.3.1 Ketika K-fold menggunakan k=5

# %%
res_dict = {
    "Poly-BoW": {
        "C": train_poly_bow_k5_res["C"],
        "$\gamma$": train_poly_bow_k5_res["gamma"],
        "Akurasi": train_poly_bow_k5_res["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "C": train_poly_tfidf_k5_res["C"],
        "$\gamma$": train_poly_tfidf_k5_res["gamma"],
        "Akurasi": train_poly_tfidf_k5_res["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict,
    "upper left",
    "Kernel Polinomial \nPelatihan (k=5): C vs. $\gamma$ vs. Akurasi"
)

# %%
res_dict = {
    "Poly-BoW": {
        "C": train_poly_bow_k5_res["C"],
        "Degree": train_poly_bow_k5_res["degree"],
        "Akurasi": train_poly_bow_k5_res["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "C": train_poly_tfidf_k5_res["C"],
        "Degree": train_poly_tfidf_k5_res["degree"],
        "Akurasi": train_poly_tfidf_k5_res["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict,
    "upper left",
    "Kernel Polinomial \nPelatihan (k=5): C vs. Degree vs. Akurasi"
)

# %%
res_dict = {
    "Poly-BoW": {
        "gamma": train_poly_bow_k5_res["gamma"],
        "Degree": train_poly_bow_k5_res["degree"],
        "Akurasi": train_poly_bow_k5_res["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "gamma": train_poly_tfidf_k5_res["gamma"],
        "Degree": train_poly_tfidf_k5_res["degree"],
        "Akurasi": train_poly_tfidf_k5_res["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict,
    "upper left",
    "Kernel Polinomial \nPelatihan (k=5): Gamma vs. Degree vs. Akurasi"
)

# %% [markdown]
# ##### 3.3.2 Ketika K-fold menggunakan k=10

# %%
res_dict = {
    "Poly-BoW": {
        "C": train_poly_bow_k10_res["C"],
        "$\gamma$": train_poly_bow_k10_res["gamma"],
        "Akurasi": train_poly_bow_k10_res["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "C": train_poly_tfidf_k10_res["C"],
        "$\gamma$": train_poly_tfidf_k10_res["gamma"],
        "Akurasi": train_poly_tfidf_k10_res["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict,
    "upper left",
    "Kernel Polinomial \nPelatihan (k=10): C vs. $\gamma$ vs. Akurasi"
)

# %%
res_dict = {
    "Poly-BoW": {
        "C": train_poly_bow_k10_res["C"],
        "Degree": train_poly_bow_k10_res["degree"],
        "Akurasi": train_poly_bow_k10_res["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "C": train_poly_tfidf_k10_res["C"],
        "Degree": train_poly_tfidf_k10_res["degree"],
        "Akurasi": train_poly_tfidf_k10_res["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict,
    "upper left",
    "Kernel Polinomial \nPelatihan (k=10): C vs. Degree vs. Akurasi"
)

# %%
res_dict = {
    "Poly-BoW": {
        "Gamma": train_poly_bow_k10_res["gamma"],
        "Degree": train_poly_bow_k10_res["degree"],
        "Akurasi": train_poly_bow_k10_res["mean_accuracy"],
    },
    "Poly-TFIDF": {
        "Gamma": train_poly_tfidf_k10_res["gamma"],
        "Degree": train_poly_tfidf_k10_res["degree"],
        "Akurasi": train_poly_tfidf_k10_res["mean_accuracy"],
    }
}

analysis.plot_performance_3d(
    res_dict,
    "upper left",
    "Kernel Polinomial \nPelatihan (k=10): Gamma vs. Degree vs. Akurasi"
)
